# %%
from sklearn import datasets
import pandas as pd

# %%
import math

# %%
iris = datasets.load_iris()

# %%
df = pd.DataFrame(iris.data)
df.columns = ["sl", "sw", 'pl', 'pw']

# %%
#Function to find label for a value
#if MIN_Value <=val < (m + Mean_Value) / 2 then it is assigned label a
#if (m + Mean_Value) <=val < Mean_Value then it is assigned label b
#if (Mean_Value) <=val < (Mean_Value + MAX_Value)/2 then it is assigned label c
#if (Mean_Value + MAX_Value)/2 <=val <= MAX_Value  then it is assigned label d

def label(val, *boundaries):
    if (val < boundaries[0]):
        return 'a'
    elif (val < boundaries[1]):
        return 'b'
    elif (val < boundaries[2]):
        return 'c'
    else:
        return 'd'

#Function to convert a continuous data into labelled data
#There are 4 lables  - a, b, c, d
def toLabel(df, old_feature_name):
    second = df[old_feature_name].mean()
    minimum = df[old_feature_name].min()
    first = (minimum + second)/2
    maximum = df[old_feature_name].max()
    third = (maximum + second)/2
    return df[old_feature_name].apply(label, args= (first, second, third))

# %%
#Convert all columns to labelled data
df['sl_labeled'] = toLabel(df, 'sl')
df['sw_labeled'] = toLabel(df, 'sw')
df['pl_labeled'] = toLabel(df, 'pl')
df['pw_labeled'] = toLabel(df, 'pw')
df
# Out:
#       sl   sw   pl   pw sl_labeled sw_labeled pl_labeled pw_labeled
# 0    5.1  3.5  1.4  0.2          b          c          a          a
# 1    4.9  3.0  1.4  0.2          a          b          a          a
# 2    4.7  3.2  1.3  0.2          a          c          a          a
# 3    4.6  3.1  1.5  0.2          a          c          a          a
# 4    5.0  3.6  1.4  0.2          a          c          a          a
# 5    5.4  3.9  1.7  0.4          b          d          a          a
# 6    4.6  3.4  1.4  0.3          a          c          a          a
# 7    5.0  3.4  1.5  0.2          a          c          a          a
# 8    4.4  2.9  1.4  0.2          a          b          a          a
# 9    4.9  3.1  1.5  0.1          a          c          a          a
# 10   5.4  3.7  1.5  0.2          b          c          a          a
# 11   4.8  3.4  1.6  0.2          a          c          a          a
# 12   4.8  3.0  1.4  0.1          a          b          a          a
# ...

# %%
df.drop(['sl', 'sw', 'pl', 'pw'], axis = 1, inplace = True)

# %%
set(df['sl_labeled'])
# Out:
# {'a', 'b', 'c', 'd'}

# %%
df.head()
# Out:
#   sl_labeled sw_labeled pl_labeled pw_labeled
# 0          b          c          a          a
# 1          a          b          a          a
# 2          a          c          a          a
# 3          a          c          a          a
# 4          a          c          a          a

# %%
import numpy as np

# %%
p=np.unique("sl_labeled")
print(p)
# Out:
# ['sl_labeled']

# %%
# making desicion tree 

class Desiciontree(object):
    def __init__(self):
        self.feature=None
        self.left=None
        self.right=None
        self.data=None
        self.split_value=None
        self.label=None
        self.count=None
        self.level=None
        
        # function to print information about node 
        def printdescription(self):
            if self.feature==0:
                print("P_w " (+str(self.feature)))
            elif self.feature==1:
                print("p_l",(self.feature))
            elif self.feature==2:
                print("s_w",self.feature)
            elif self.feature==3:
                print("s_l",self.feature)
                
        #function to print label value and count of that value in a feature        
        def printlabel(self):
            print("Label "+str(self.label)+ " count is "+str(self.count))
        
        # printng node and information about it
        def printnode(self):
            if self.left is None and self.right is None:
                print(" leaf Node ")
                self.printlabel()
                
            else :
                self.printdescription()
                self.left.printnode()
                self.right.printnode()
        
        # function to count number of values in data
        def getcount(data):
            count=[0,0,0]
            for i in range(len(data)):
                    y=int(data[i][-1])
                    count[y-1]+=1
            
            return count
         # function to check if we reached a pure node
        
        def pure(data):
            count=getcount(data)
            check=0
            total=0
            label=-1
            
            for x in range(len(count)):
                if count[x]>0:
                    flag+=1
                    label=x+1
                    
                    total+=count[x]
                    
            if flag==1:
                return (label,total)
            
            else:
                return (-1,total)
            
         # spliting of data on a value using this function   
        def splitdata(self,data,feature,split_value):
            left_set=[]
            right_set=[]
            for i in range(len(data)):
                if data[i][feature]<=split_value:
                    left_set.append(data[x])
                else :
                    right_set.append(data[x])
                    
            return (left_set,right_set)
        
        # function to calculate entropy of a data before split
        def entropy(data):
            e=0.0
            count=getcount(data)
            for i in range(len(count)):
                p=count[i]/len(count)
                if(p!=0):
                    e+=-(p*np.math.log10(pi))
                    
            return entropy
        
        
        # function to calulate entropy after split
        def entropyaftersplit(data,feature,split_value):
            left_set,right_set=splitdata(data,feature,split_value)
            
            total=len(left_set)/len(data)*entropy(left_set)
            total+=len(right_set)/len(data)*entropy(right_set)
            return total
        
        # calculating info gain 
        def gain(data,feature,split_value):
            gain=entropy(data)-entropyaftersplit(data,feature,split_value)
            
            return gain

# %%
def build_tree(df,unused_features,level):
    
    #base case
    
    # 1. unused is empty
    
    if(len(unused_features)==0):
        return node
    c=Desiciontree()
    label,count=c.pure(df)
    
    # 2. y contains only one distinct value
    if(label!=-1):
        node=Desiciontree()
        node.label=label
        node.count=count
        node.level=level
            
        return node;
        
    else :
        
            
        maxgain=0
        best_feature = ""
        for f in unused_features:
            possible_values = set(df[f])
            print(possible_values)
        
        # loop over possible values : val
            for x in possible_values:
                maxgain_value_split=0
            
        #  finding gain if splitted along a value
                infogain=gain(df,f,x)
            
            #finding optimal value to split using maximum gain
                if(maxgain_value_split<infogain):
                    maxgain_value_split=infogain
                    value=x
                
        # storing max gain if splitted on a particular feature
            if(maxgain<maxgain_value_split):
                maxgain=maxgain_value_split
                best_feature=f                  # storing best feature on which max gain found
            
            
    
            
        
        
        # loop over possible values : val
        # find subset of df & y with f == val
        # find number of mistakes in this subset 
        # if we predict the most common y as the output
        # find sum of all these mistakes
        # update best feature so that that particular feature
        # makes least number of mistakes
        
        # here you should know the best feature
        # print it out
        print("Best Feature ", best_feature)
    
        # deleting best feature from unused_features
    
        unused_features.remove(best_feature)
     #making object  of tree and intilizing values of tree
        node= Desiciontree()
        node.feature=best_feature
        node.split_value=value
        node.count=count
        node.level=level
    
     # loop over possible values of best feature
    # splitiing data on best feature 
        left_set,right_set=splitdata(dataset,feature,split_value)

    
     # call build tree recursively
        node.left=build_tree(left_level+1)
        node.right=build_tree(right_level+1)
    
        return node

# %%
y = pd.DataFrame(iris.target)
unused_features = set(df.columns)
print(unused_features)
root=build_tree(df,unused_features,0)
root.printnode()
# Out:
# {'sl_labeled', 'pw_labeled', 'pl_labeled', 'sw_labeled'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-61aceb361a84> in <module>
#       2 unused_features = set(df.columns)
#       3 print(unused_features)
# ----> 4 root=build_tree(df,unused_features,0)
#       5 root.printnode()
#
# <ipython-input-13-afdeab2fca35> in build_tree(df, unused_features, level)
#       8         return node
#       9     c=Desiciontree()
# ---> 10     label,count=c.pure(df)
#      11
#      12     # 2. y contains only one distinct value
#
# AttributeError: 'Desiciontree' object has no attribute 'pure'
